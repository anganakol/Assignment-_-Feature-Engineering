# %% [markdown]
# 1. What is a parameter?
#
# ans- Hypothesis testing is a statistical method used to make inferences about a population parameter based on sample data. It involves formulating a hypothesis about the population, collecting data, and then using statistical tests to determine whether the data supports or rejects the hypothesis.
#
# 2. What is correlation? What does negative correlation mean?
#
# ans- Correlation measures the statistical relationship between two variables. It quantifies how strongly two variables are related and the direction of that relationship.
#
# Negative correlation means that two variables move in opposite directions. When one variable increases, the other tends to decrease, and vice versa. For example, there might be a negative correlation between the number of hours spent studying and the number of errors on an exam.
#
# 3. Define Machine Learning. What are the main components in Machine Learning?
#
# ans- Machine Learning is a field of artificial intelligence that allows computers to learn from data without being explicitly programmed.
#
# Data
# Features
# Algorithms
# Model
# Evaluation
#
# 4. How does loss value help in determining whether the model is good or not?
#
# ans- The loss value quantifies how well the model's predictions match the actual values in the data. A lower loss value generally indicates a better-performing model.
#
# 5. What are continuous and categorical variables?
#
# ans- Continuous Variables: Can take on any value within a given range (e.g., temperature, height, weight).
# Categorical Variables: Can take on a limited number of values (e.g., color, gender, country).
#
# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# ans- Encoding: We need to convert categorical variables into numerical representations that the model can understand. Common techniques include:
# One-Hot Encoding: Creates a new binary column for each category.
# Label Encoding: Assigns a unique integer to each category.
# Ordinal Encoding: Assigns an integer based on the order of the categories.
#
# 7. What do you mean by training and testing a dataset?
#
# ans- Training Data: Used to train the model and teach it to identify patterns and relationships.
# Testing Data: Used to evaluate the model's performance on unseen data and assess its ability to generalize.
#
# 8. What is sklearn.preprocessing?
#
# ans- sklearn.preprocessing is a submodule in the scikit-learn library in Python that provides tools for data preprocessing, such as scaling, encoding, and normalization.
#
# 9. What is a Test set?
#
# ans- The test set is a portion of the data that is held back during the training process. It is used to evaluate the model's performance on unseen data to assess its ability to generalize.
#
# 10. How do we split data for model fitting (training and testing) in Python?
#
# ans- We can use the train_test_split() function from the sklearn.model_selection module. This function randomly splits the data into training and testing sets with a specified ratio (e.g., 80% for training and 20% for testing).
#
# 11. Why do we have to perform EDA before fitting a model to the data?
#
# ans- Exploratory Data Analysis (EDA) is crucial for understanding the data and identifying potential issues before building a model. It helps in:
# Identifying patterns, trends, and relationships.
# Detecting outliers and anomalies.
# Handling missing values.
# Selecting appropriate features for the model.
#
# 12. What is correlation?
#
# ans- Correlation measures the statistical relationship between two variables. It quantifies how strongly two variables are related and the direction of that relationship.
#
# 13. What does negative correlation mean?
#
# ans- Negative correlation means that two variables move in opposite directions. When one variable increases, the other tends to decrease, and vice versa.
#
# 14. How can you find correlation between variables in Python?
#
# ans- Use the corr() method in pandas to calculate the correlation matrix between variables in a DataFrame.
#
# 15. What is causation? Explain the difference between correlation and causation with an example.
#
# ans- Causation implies that one variable directly causes a change in another.
#
# Correlation simply indicates a relationship between two variables, but it doesn't necessarily mean that one causes the other.
#
# Example: Ice cream sales and drowning deaths are often correlated. However, eating ice cream does not cause people to drown. The correlation is likely due to a third factor: warm weather.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# ans- Optimizer: An algorithm that adjusts the model's parameters to minimize the loss function and improve the model's performance.
# Types:
# Gradient Descent: Iteratively adjusts parameters in the direction of the steepest descent of the loss function.
# Stochastic Gradient Descent (SGD): Similar to gradient descent, but uses a single data point or a small batch of data to update parameters.
# Adam: A more advanced optimizer that combines the benefits of other optimizers like AdaGrad and RMSprop.
#
# 17. What is sklearn.linear_model?
#
# ans- sklearn.linear_model is a submodule in scikit-learn that provides implementations of various linear models, such as Linear Regression, Logistic Regression, and Ridge Regression.
#
# 18. What does model.fit() do? What arguments must be given?
#
# ans- model.fit() trains the machine learning model on the given training data.
# Arguments typically include the training data features (X_train) and the corresponding target variable (y_train).
#
# 19. What does model.predict() do? What arguments must be given?
#
# ans- model.predict() makes predictions on new, unseen data using the trained model.
# The argument is usually the feature data for which we want to make predictions (X_test).
#
# 20. What are continuous and categorical variables?
#
# ans- Continuous Variables: Can take on any value within a given range (e.g., temperature, height, weight).
# Categorical Variables: Can take on a limited number of values (e.g., color, gender, country).
#
# 21. What is feature scaling? How does it help in Machine Learning?
#
# ans- Feature scaling is the process of transforming the features of the data to a common scale.
# It helps in:
# Improving model performance by preventing features with larger values from dominating the learning process.
# Ensuring that all features contribute equally to the model.
# Making the model more robust to outliers.
#
# 22. How do we perform scaling in Python?
#
# ans-  Use the StandardScaler, MinMaxScaler, or RobustScaler classes from the sklearn.preprocessing module.
#
# 23. What is sklearn.preprocessing?
#
# ans- sklearn.preprocessing is a submodule in scikit-learn that provides tools for data preprocessing, such as scaling, encoding, and normalization.
#
# 24. How do we split data for model fitting (training and testing) in Python?
#
# ans- We can use the train_test_split() function from the sklearn.model_selection module. This function randomly splits the data into training and testing sets with a specified ratio (e.g., 80% for training and 20% for testing).
#
# 25. Explain data encoding?
#
# ans- Data encoding is the process of converting categorical variables into numerical representations that the model can understand.
